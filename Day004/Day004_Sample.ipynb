# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 下載檔案

# %%
import sys
print(sys.executable)
# Out:
# c:\users\bobson\.virtualenvs\pycrawler-nnr4qheg\scripts\python.exe

# %%
import requests

r = requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"10965798373","type":"PushEvent","actor":{"id":834149,"login":"carltonj2000","display_login":"carltonj2000","gravatar_id":"","url":"https://api.github.com/users/carltonj2000","avatar_url":"https://avatars.githubusercontent.com/u/834149?"},"repo":{"id":224544009,"name":"carltonj2000/hello-actions","url":"https://api.github.com/repos/carltonj2000/hello-actions"},"payload":{"push_id":4330309405,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"1021342325ee18caa20ed838945eb3bb1bc077cc","before":"f5a552621ec067899c0e7f737841ff814f800b08","commits":[{"sha":"1021342325ee18caa20ed838945eb3bb1bc077cc","author":{"email":"carlton.joseph@gmail.com","name":"Carlton Joseph"},"message":"update gh action to build release branch","distinct":true,"url":"https://api.github.com/repos/carltonj2000/hello-actions/commits/1021342325ee18caa20ed838945eb3bb1bc077cc"}]},"public":true,"created_at":"2019-11-28T04:31:49Z"},{"id":"10965798368","type":"PushEvent","actor":{"id":17193977,"login":"newstools","display_login":"newstools","gravatar_id":"","url":"https://api.github.com/users/newstools","avatar_url":"https://avatars.githubusercontent.com/u/17193977?"},"repo":{"id":184117402,"name":"newstools/2019-naija-news-agency","url":"https://api.github.com/repos/newstools/2019-naija-news-agency"},"payload":{"push_id":4330309401,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"e65899254cf6f2766fe1dd051a227e2631c1772a","before":"ac7a4fe385590b65ed4edec13aae7309fc523587","commits":[{"sha":"e65899254cf6f2766fe1dd051a227e2631c1772a","author":{"email":"github@newstools.co.za","name":"NewsTools"},"message":"Created Text For URL [naijanewsagency.com/emery-seeks-europa-league-comfort-as-man-united-battle-kazakhstans-astana/]","distinct":true,"url":"https://api.github.com/repos/newstools/2019-naija-news-agency/commits/e65899254cf6f2766fe1dd051a227e2631c1772a"}]},"public":true,"created_at":"2019-11-28T04:31:49Z"},{"id":"10965798370","type":"PushEvent","actor":{"id":55603058,"login":"stevin-wilson","display_login":"stevin-wilson","gravatar_id":"","url":"https://api.github.com/users/stevin-wilson","avatar_url":"https://avatars.githubusercontent.com/u/55603058?"},"repo":{"id":224568940,"name":"stevin-wilson/PrositePatternsToPythonRegex","url":"https://api.github.com/repos/stevin-wilson/PrositePatternsToPythonRegex"},"payload":{"push_id":4330309404,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"adab4545fbc597877d579c8e4cf0ca4467ce4d56","before":"0b5626937319e0e0b2b51c7408278437c797789d","commits":[{"sha":"adab4545fbc597877d579c8e4cf0ca4467ce4d56","author":{"email":"stevin@Stevins-MacBook-Pro.local","name":"Stevin Wilson"},"message":"When [X>], output two Regex separated by <tab>&<tab>","distinct":true,"url":"https://api.github.com/repos/stevin-wilson/PrositePatternsToPythonRegex/commits/adab4545fbc597877d579c8e4cf0ca4467ce4d56"}]},"public":true,"created_at":"2019-11-28T04:31:49Z"},{"id":"10965798371","type":"CreateEvent","actor":{"id":57339551,"login":"vasanthakumars98","display_login":"vasanthakumars98","gravatar_id":"","url":"https://api.github.com/users/vasanthakumars98","avatar_url":"https://avatars.githubusercontent.com/u/57339551?"},"repo":{"id":224570068,"name":"vasanthakumars98/my-farm1","url":"https://api.github.com/repos/vasanthakumars98/my-farm1"},"payload":{"ref":null,"ref_type":"repository","master_branch":"master","description":null,"pusher_type":"user"},"public":true,"created_at":"2019-11-28T04:31:49Z"},{"id":"10965798366","type":"PushEvent","actor":{"id":40927102,"login":"yuzhechuan","display_login":"yuzhechuan","gravatar_id":"","url":"https://api.github.com/users/yuzhechuan","avatar_url":"https://avatars.githubusercontent.com/u/40927102?"},"repo":{"id":217087923,"name":"yuzhechuan/yuzhechuan.github.io","url":"https://api.github.com/repos/yuzhechuan/yuzhechuan.github.io"},"payload":{"push_id":4330309398,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"e02dc5a7224461cc67e39d402a4d867d832e4148","before":"55 ...

# %%
import json

json.loads(r.text)
# Out:
# [{'id': '9911330792',
#   'type': 'PushEvent',
#   'actor': {'id': 11312017,
#    'login': 'pbaffiliate4',
#    'display_login': 'pbaffiliate4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/pbaffiliate4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11312017?'},
#   'repo': {'id': 153577238,
#    'name': 'pbaffiliate4/repoForSettings',
#    'url': 'https://api.github.com/repos/pbaffiliate4/repoForSettings'},
#   'payload': {'push_id': 3762296191,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'be9d8ea6b6737192cd4710bf8884125c92acbcc5',
#    'before': 'bc9fd090c7811ba2b489ef60571abd8c5d413f23',
#    'commits': [{'sha': 'be9d8ea6b6737192cd4710bf8884125c92acbcc5',
#      'author': {'email': 'pbaffiliate4@gmail.com', 'name': 'Afaf Zakhya'},
#      'message': 'Test - Clear repository branch',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/pbaffiliate4/repoForSettings/commits/be9d8ea6b6737192cd4710bf8884125c92acbcc5'}]},
#   'public': True,
#   'created_at': '2019-06-28T05:28:39Z'},
#  {'id': '9911330783',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 10598,
#    'login': 'ketan',
#    'display_login': 'ketan',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ketan',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10598?'},
#   'repo': {'id': 15217919,
#    'name': 'gocd/www.go.cd',
#    'url': 'https://api.github.com/repos/gocd/www.go.cd'},
#   'payload': {'action': 'closed',
#    'number': 975,
#    'pull_request': {'url': 'https://api.github.com/repos/gocd/www.go.cd/pulls/975',
#     'id': 278535640,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0Mjc4NTM1NjQw',
#     'html_url': 'https://github.com/gocd/www.go.cd/pull/975',
#     'diff_url': 'https://github.com/gocd/www.go.cd/pull/975.diff',
#     'patch_url': 'https://github.com/gocd/www.go.cd/pull/975.patch',
#     'issue_url': 'https://api.github.com/repos/gocd/www.go.cd/issues/975',
#     'number': 975,
#     'state': 'closed',
#     'locked': False,
#     'title': 'Bump middleman from 4.3.2 to 4.3.4',
#     'user': {'login': 'dependabot-preview[bot]',
#      'id': 27856297,
#      'node_id': 'MDM6Qm90Mjc4NTYyOTc=',
#      'avatar_url': 'https://avatars3.githubusercontent.com/in/2141?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot-preview',
#      'followers_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'body': 'Bumps [middleman](https://github.com/middleman/middleman) from 4.3.2 to 4.3.4.\n<details>\n<summary>Commits</summary>\n\n- [`9482996`](https://github.com/middleman/middleman/commit/9482996d0c97bfc1d5949fa0527fb3cac3516734) Disable bind test on travis\n- [`8091cb4`](https://github.com/middleman/middleman/commit/8091cb469847bb3e83ec5dd649b0437ebb6ddaa1) Lock old bundler\n- [`ab1fc00`](https://github.com/middleman/middleman/commit/ab1fc00e6e569588c06a2cd5795f9a5e2da2e8ae) Bump minor\n- [`b450db2`](https://github.com/middleman/middleman/commit/b450db2fc4317220bbddf6c45397d74cbbc73b41) Fix ignore of I18n files ([#2143](https://github-redirect.dependabot.com/middleman/middleman/issues/2143))\n- [`f67ae38`](https://github.com/middleman/middleman/commit/f67ae38da59551c1629f70d7ca780b8402c3ae93) Bump again\n- [`d53e3c6`](https://github.com/middleman/middleman/commit/d53e3c6d8ff6fdf90e1f58b79cd6df0b9f804035) Bump\n- [`95c234f`](https://github.com/middleman/middleman/commit/95c234f7194ba8916b108082b788d774cf73f0e9) Add --bail option to fail upon first error ([#2246](https://github-redirect.dependabot.com/middleman/middleman/issues/2246))\n- [`fc01a6c`](https://github.com/middleman/middleman/commit/fc01a6c4b823056f262324d7fc05b306319d469c) Fix lambda syntax\n- [`dae9203`](https://github.com/middleman/middleman/commit/dae9203e8c9b7973c3f15d17d421ec89949d5777) Feature: Add an option to create asset hashes without using the original file...\n- See full diff in [compare view](https://github.com/middleman/middleman/compare/v4.3.2...v4.3.4)\n</details>\n<br />\n\n[![Dependabot compatibility score](https://api.dependabot.com/badges/compatibility_score?dependency-name=middleman&package-manager=bundler&previous-version=4.3.2&new-version=4.3.4)](https://dependabot.com/compatibility-score.html?dependency-name=middleman&package-manager=bundler&previous-version=4.3.2&new-version=4.3.4)\n\nDependabot will resolve any conflicts with this PR as long as you don\'t alter it yourself. You can also trigger a rebase manually by commenting `@dependabot rebase`.\n\n[//]: # (dependabot-automerge-start)\n[//]: # (dependabot-automerge-end)\n\n---\n\n<details>\n<summary>Dependabot commands and options</summary>\n<br />\n\nYou can trigger Dependabot actions by commenting on this PR:\n- `@dependabot rebase` will rebase this PR\n- `@dependabot recreate` will recreate this PR, overwriting any edits that have been made to it\n- `@dependabot merge` will merge this PR after your CI passes on it\n- `@dependabot squash and merge` will squash and merge this PR after your CI passes on it\n- `@dependabot cancel merge` will cancel a previously requested merge and block automerging\n- `@dependabot reopen` will reopen this PR if it is closed\n- `@dependabot ignore this [patch|minor|major] version` will close this PR and stop Dependabot creating any more for this minor/major version (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot ignore this dependency` will close this PR and stop Dependabot creating any more for this dependency (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot use these labels` will set the current labels as the default for future PRs for this repo and language\n- `@dependabot use these reviewers` will set the current reviewers as the default for future PRs for this repo and language\n- `@dependabot use these assignees` will set the current assignees as the default for future PRs for this repo and language\n- `@dependabot use this milestone` will set the current milestone as the default for future PRs for this repo and language\n- `@dependabot badge me` will comment on this PR with code to add a "Dependabot enabled" badge to your readme\n\nAdditionally, you can set the following in your Dependabot [dashboard](https://app.dependabot.com):\n- Update frequency (including time of day and day of week)\n- Automerge options (never/patch/minor, and dev/runtime dependencies)\n- Pull request limits (per update run and/or ...
#     'created_at': '2019-05-14T06:23:29Z',
#     'updated_at': '2019-06-28T05:28:39Z',
#     'closed_at': '2019-06-28T05:28:39Z',
#     'merged_at': '2019-06-28T05:28:39Z',
#     'merge_commit_sha': '2a0bca4c51036df50db45f1cbe61aa6c3f2cd2f6',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [{'id': 1186592167,
#       'node_id': 'MDU6TGFiZWwxMTg2NTkyMTY3',
#       'url': 'https://api.github.com/repos/gocd/www.go.cd/labels/dependencies',
#       'name': 'dependencies',
#       'color': '0025ff',
#       'default': False}],
#     'milestone': None,
#     'commits_url': 'https://api.github.com/repos/gocd/www.go.cd/pulls/975/commits',
#     'review_comments_url': 'https://api.github.com/repos/gocd/www.go.cd/pulls/975/comments',
#     'review_comment_url': 'https://api.github.com/repos/gocd/www.go.cd/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/gocd/www.go.cd/issues/975/comments',
#     'statuses_url': 'https://api.github.com/repos/gocd/www.go.cd/statuses/3f17cd5a5ca018666bed97f4e07ae4c707ae675c',
#     'head': {'label': 'gocd:dependabot/bundler/middleman-4.3.4',
#      'ref': 'dependabot/bundler/middleman-4.3.4',
#      'sha': '3f17cd5a5ca018666bed97f4e07ae4c707ae675c',
#      'user': {'login': 'gocd',
#       'id': 6099846,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjYwOTk4NDY=',
#       'avatar_url': 'https://avatars1.githubusercontent.com/u/6099846?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/gocd',
#       'html_url': 'https://github.com/gocd',
#       'followers_url': 'https://api.github.com/users/gocd/followers',
#       'following_url': 'https://api.github.com/users/gocd/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/gocd/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/gocd/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/gocd/subscriptions',
#       'organizations_url': 'https://api.github.com/users/gocd/orgs',
#       'repos_url': 'https://api.github.com/users/gocd/repos',
#       'events_url': 'https://api.github.com/users/gocd/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/gocd/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 15217919,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxNTIxNzkxOQ==',
#       'name': 'www.go.cd',
#       'full_name': 'gocd/www.go.cd',
#       'private': False,
#       'owner': {'login': 'gocd',
#        'id': 6099846,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjYwOTk4NDY=',
#        'avatar_url': 'https://avatars1.githubusercontent.com/u/6099846?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/gocd',
#        'html_url': 'https://github.com/gocd',
#        'followers_url': 'https://api.github.com/users/gocd/followers',
#        'following_url': 'https://api.github.com/users/gocd/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/gocd/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/gocd/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/gocd/subscriptions',
#        'organizations_url': 'https://api.github.com/users/gocd/orgs',
#        'repos_url': 'https://api.github.com/users/gocd/repos',
#        'events_url': 'https://api.github.com/users/gocd/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/gocd/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/gocd/www.go.cd',
#       'description': 'Github pages repo ',
#       'fork': False,
#       'url': 'https://api.github.com/repos/gocd/www.go.cd',
#       'forks_url': 'https://api.github.com/repos/gocd/www.go.cd/forks',
#       'keys_url': 'https://api.github.com/repos/gocd/www.go.cd/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/gocd/www.go.cd/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/gocd/www.go.cd/teams',
#       'hooks_url': 'https://api.github.com/repos/gocd/www.go.cd/hooks',
#       'issue_events_url': 'https://api.github.com/repos/gocd/www.go.cd/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/gocd/www.go.cd/events',
#       'assignees_url': 'https://api.github.com/repos/gocd/www.go.cd/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/gocd/www.go.cd/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/gocd/www.go.cd/tags',
#       'blobs_url': 'https://api.github.com/repos/gocd/www.go.cd/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/gocd/www.go.cd/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/gocd/www.go.cd/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/gocd/www.go.cd/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/gocd/www.go.cd/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/gocd/www.go.cd/languages',
#       'stargazers_url': 'https://api.github.com/repos/gocd/www.go.cd/stargazers',
#       'contributors_url': 'https://api.github.com/repos/gocd/www.go.cd/contributors',
#       'subscribers_url': 'https://api.github.com/repos/gocd/www.go.cd/subscribers',
#       'subscription_url': 'https://api.github.com/repos/gocd/www.go.cd/subscription',
#       'commits_url': 'https://api.github.com/repos/gocd/www.go.cd/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/gocd/www.go.cd/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/gocd/www.go.cd/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/gocd/www.go.cd/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/gocd/www.go.cd/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/gocd/www.go.cd/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/gocd/www.go.cd/merges',
#       'archive_url': 'https://api.github.com/repos/gocd/www.go.cd/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/gocd/www.go.cd/downloads',
#       'issues_url': 'https://api.github.com/repos/gocd/www.go.cd/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/gocd/www.go.cd/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/gocd/www.go.cd/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/gocd/www.go.cd/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/gocd/www.go.cd/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/gocd/www.go.cd/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/gocd/www.go.cd/deployments',
#       'created_at': '2013-12-16T05:36:20Z',
#       'updated_at': '2019-06-28T05:22:55Z',
#       'pushed_at': '2019-06-28T05:28:39Z',
#       'git_url': 'git://github.com/gocd/www.go.cd.git',
#       'ssh_url': 'git@github.com:gocd/www.go.cd.git',
#       'clone_url': 'https://github.com/gocd/www.go.cd.git',
#       'svn_url': 'https://github.com/gocd/www.go.cd',
#       'homepage': 'https://www.gocd.org',
#       'size': 199801,
#       'stargazers_count': 40,
#       'watchers_count': 40,
#       'language': 'HTML',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': True,
#       'forks_count': 111,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 26,
#       'license': {'key': 'apache-2.0',
#        'name': 'Apache License 2.0',
#        'spdx_id': 'Apache-2.0',
#        'url': 'https://api.github.com/licenses/apache-2.0',
#        'node_id': 'MDc6TGljZW5zZTI='},
#       'forks': 111,
#       'open_issues': 26,
#       'watchers': 40,
#       'default_branch': 'master'}},
#     'base': {'label': 'gocd:master',
#      'ref': 'master',
#      'sha': '21853a9f329ed91b4e389896356312c35a33983e',
#      'user': {'login': 'gocd',
#       'id': 6099846,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjYwOTk4NDY=',
#       'avatar_url': 'https://avatars1.githubusercontent.com/u/6099846?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/gocd',
#       'html_url': 'https://github.com/gocd',
#       'followers_url': 'https://api.github.com/users/gocd/followers',
#       'following_url': 'https://api.github.com/users/gocd/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/gocd/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/gocd/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/gocd/subscriptions',
#       'organizations_url': 'https://api.github.com/users/gocd/orgs',
#       'repos_url': 'https://api.github.com/users/gocd/repos',
#       'events_url': 'https://api.github.com/users/gocd/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/gocd/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 15217919,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxNTIxNzkxOQ==',
#       'name': 'www.go.cd',
#       'full_name': 'gocd/www.go.cd',
#       'private': False,
#       'owner': {'login': 'gocd',
#        'id': 6099846,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjYwOTk4NDY=',
#        'avatar_url': 'https://avatars1.githubusercontent.com/u/6099846?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/gocd',
#        'html_url': 'https://github.com/gocd',
#        'followers_url': 'https://api.github.com/users/gocd/followers',
#        'following_url': 'https://api.github.com/users/gocd/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/gocd/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/gocd/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/gocd/subscriptions',
#        'organizations_url': 'https://api.github.com/users/gocd/orgs',
#        'repos_url': 'https://api.github.com/users/gocd/repos',
#        'events_url': 'https://api.github.com/users/gocd/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/gocd/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/gocd/www.go.cd',
#       'description': 'Github pages repo ',
#       'fork': False,
#       'url': 'https://api.github.com/repos/gocd/www.go.cd',
#       'forks_url': 'https://api.github.com/repos/gocd/www.go.cd/forks',
#       'keys_url': 'https://api.github.com/repos/gocd/www.go.cd/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/gocd/www.go.cd/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/gocd/www.go.cd/teams',
#       'hooks_url': 'https://api.github.com/repos/gocd/www.go.cd/hooks',
#       'issue_events_url': 'https://api.github.com/repos/gocd/www.go.cd/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/gocd/www.go.cd/events',
#       'assignees_url': 'https://api.github.com/repos/gocd/www.go.cd/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/gocd/www.go.cd/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/gocd/www.go.cd/tags',
#       'blobs_url': 'https://api.github.com/repos/gocd/www.go.cd/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/gocd/www.go.cd/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/gocd/www.go.cd/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/gocd/www.go.cd/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/gocd/www.go.cd/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/gocd/www.go.cd/languages',
#       'stargazers_url': 'https://api.github.com/repos/gocd/www.go.cd/stargazers',
#       'contributors_url': 'https://api.github.com/repos/gocd/www.go.cd/contributors',
#       'subscribers_url': 'https://api.github.com/repos/gocd/www.go.cd/subscribers',
#       'subscription_url': 'https://api.github.com/repos/gocd/www.go.cd/subscription',
#       'commits_url': 'https://api.github.com/repos/gocd/www.go.cd/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/gocd/www.go.cd/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/gocd/www.go.cd/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/gocd/www.go.cd/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/gocd/www.go.cd/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/gocd/www.go.cd/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/gocd/www.go.cd/merges',
#       'archive_url': 'https://api.github.com/repos/gocd/www.go.cd/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/gocd/www.go.cd/downloads',
#       'issues_url': 'https://api.github.com/repos/gocd/www.go.cd/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/gocd/www.go.cd/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/gocd/www.go.cd/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/gocd/www.go.cd/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/gocd/www.go.cd/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/gocd/www.go.cd/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/gocd/www.go.cd/deployments',
#       'created_at': '2013-12-16T05:36:20Z',
#       'updated_at': '2019-06-28T05:22:55Z',
#       'pushed_at': '2019-06-28T05:28:39Z',
#       'git_url': 'git://github.com/gocd/www.go.cd.git',
#       'ssh_url': 'git@github.com:gocd/www.go.cd.git',
#       'clone_url': 'https://github.com/gocd/www.go.cd.git',
#       'svn_url': 'https://github.com/gocd/www.go.cd',
#       'homepage': 'https://www.gocd.org',
#       'size': 199801,
#       'stargazers_count': 40,
#       'watchers_count': 40,
#       'language': 'HTML',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': True,
#       'forks_count': 111,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 26,
#       'license': {'key': 'apache-2.0',
#        'name': 'Apache License 2.0',
#        'spdx_id': 'Apache-2.0',
#        'url': 'https://api.github.com/licenses/apache-2.0',
#        'node_id': 'MDc6TGljZW5zZTI='},
#       'forks': 111,
#       'open_issues': 26,
#       'watchers': 40,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/gocd/www.go.cd/pulls/975'},
#      'html': {'href': 'https://github.com/gocd/www.go.cd/pull/975'},
#      'issue': {'href': 'https://api.github.com/repos/gocd/www.go.cd/issues/975'},
#      'comments': {'href': 'https://api.github.com/repos/gocd/www.go.cd/issues/975/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/gocd/www.go.cd/pulls/975/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/gocd/www.go.cd/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/gocd/www.go.cd/pulls/975/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/gocd/www.go.cd/statuses/3f17cd5a5ca018666bed97f4e07ae4c707ae675c'}},
#     'author_association': 'CONTRIBUTOR',
#     'merged': True,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': {'login': 'ketan',
#      'id': 10598,
#      'node_id': 'MDQ6VXNlcjEwNTk4',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/10598?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/ketan',
#      'html_url': 'https://github.com/ketan',
#      'followers_url': 'https://api.github.com/users/ketan/followers',
#      'following_url': 'https://api.github.com/users/ketan/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/ketan/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/ketan/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/ketan/subscriptions',
#      'organizations_url': 'https://api.github.com/users/ketan/orgs',
#      'repos_url': 'https://api.github.com/users/ketan/repos',
#      'events_url': 'https://api.github.com/users/ketan/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/ketan/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 6,
#     'deletions': 6,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2019-06-28T05:28:39Z',
#   'org': {'id': 6099846,
#    'login': 'gocd',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/gocd',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6099846?'}},
#  {'id': '9911330776',
#   'type': 'PushEvent',
#   'actor': {'id': 42781255,
#    'login': 'ThomasUtsey',
#    'display_login': 'ThomasUtsey',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ThomasUtsey',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/42781255?'},
#   'repo': {'id': 185896674,
#    'name': 'labslibrarypt3/LabsLibraryPT3_BE',
#    'url': 'https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE'},
#   'payload': {'push_id': 3762296184,
#    'size': 11,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '0db8637f12da6713066c21c16a1579962cd7f479',
#    'before': 'ba5970c90e5d259bb8e22fad77529a99fd214784',
#    'commits': [{'sha': '982d12420e7d62147780acefcf356cdf360c6401',
#      'author': {'email': 'ira.d.sanchez@gmail.com', 'name': 'iradsanchez'},
#      'message': "Merge branch 'tom-restricted' of https://github.com/labslibrarypt3/LabsLibraryPT3_BE into ira-sanchez",
#      'distinct': False,
#      'url': 'https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/commits/982d12420e7d62147780acefcf356cdf360c6401'},
#     {'sha': '0db817abaa3ea50bcb4593a4ed92c8f5a7e5b474',
#      'author': {'email': 'ira.d.sanchez@gmail.com', 'name': 'iradsanchez'},
#      'message': "Merge branch 'development' of https://github.com/labslibrarypt3/LabsLibraryPT3_BE into ira-sanchez",
#      'distinct': False,
#      'url': 'https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/commits/0db817abaa3ea50bcb4593a4ed92c8f5a7e5b474'},
#     {'sha': '6c5b83b07918de0ca11f2a63d8f8dc30e8e8f39f',
#      'author': {'email': 'tom@edgegluer.com', 'name': 'unknown'},
#      'message': 'Add twilio functionality',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/commits/6c5b83b07918de0ca11f2a63d8f8dc30e8e8f39f'},
#     {'sha': '9ade2086ab50e8f07e4627ca6b343ab257a5e68f',
#      'author': {'email': '42781255+ThomasUtsey@users.noreply.github.com',
#       'name': 'ThomasUtsey'},
#      'message': 'Merge pull request #75 from labslibrarypt3/tom-restricted\n\nAdd twilio functionality',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/commits/9ade2086ab50e8f07e4627ca6b343ab257a5e68f'},
#     {'sha': '8667daac0a2d2067e587b95613ad1ca5ed1df187',
#      'author': {'email': 'ira.d.sanchez@gmail.com', 'name': 'iradsanchez'},
#      'message': 'Refactor to Stripe Express',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/commits/8667daac0a2d2067e587b95613ad1ca5ed1df187'},
#     {'sha': '278a29c6426325adee0f5de64e46224061260185',
#      'author': {'email': 'ira.d.sanchez@gmail.com', 'name': 'iradsanchez'},
#      'message': 'merge conflicts',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/commits/278a29c6426325adee0f5de64e46224061260185'},
#     {'sha': '635461aa58d98f80ba37ccd0a70a6c4521409838',
#      'author': {'email': 'ira.d.sanchez@gmail.com', 'name': 'iradsanchez'},
#      'message': 'Add Stripe Redirect\n\nRedirect itself is working, but when sending a verification text, it breaks. Stripe is working on a solution and will get back to me.',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/commits/635461aa58d98f80ba37ccd0a70a6c4521409838'},
#     {'sha': 'b00d0c8330d1e6758e7e98915b99177a4518e7cc',
#      'author': {'email': 'tom@edgegluer.com', 'name': 'unknown'},
#      'message': ' username now rendering to the chat box',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/commits/b00d0c8330d1e6758e7e98915b99177a4518e7cc'},
#     {'sha': '93ee8684d13afb717655911f23c75bf6a5f0766b',
#      'author': {'email': '42781255+ThomasUtsey@users.noreply.github.com',
#       'name': 'ThomasUtsey'},
#      'message': 'Merge pull request #76 from labslibrarypt3/tom-restricted\n\n username now rendering to the chat box',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/commits/93ee8684d13afb717655911f23c75bf6a5f0766b'},
#     {'sha': '26ec0d6fffff65448247d7e8b95863a6bea94031',
#      'author': {'email': '42781255+ThomasUtsey@users.noreply.github.com',
#       'name': 'ThomasUtsey'},
#      'message': 'Merge pull request #77 from labslibrarypt3/ira-sanchez\n\nIra sanchez',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/commits/26ec0d6fffff65448247d7e8b95863a6bea94031'},
#     {'sha': '0db8637f12da6713066c21c16a1579962cd7f479',
#      'author': {'email': '42781255+ThomasUtsey@users.noreply.github.com',
#       'name': 'ThomasUtsey'},
#      'message': 'Merge pull request #78 from labslibrarypt3/development\n\nDevelopment',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/labslibrarypt3/LabsLibraryPT3_BE/commits/0db8637f12da6713066c21c16a1579962cd7f479'}]},
#   'public': True,
#   'created_at': '2019-06-28T05:28:39Z',
#   'org': {'id': 50470163,
#    'login': 'labslibrarypt3',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/labslibrarypt3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/50470163?'}},
#  {'id': '9911330773',
#   'type': 'CreateEvent',
#   'actor': {'id': 12807798,
#    'login': 'augsun',
#    'display_login': 'augsun',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/augsun',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/12807798?'},
#   'repo': {'id': 171888030,
#    'name': 'augsun/JXCapital',
#    'url': 'https://api.github.com/repos/augsun/JXCapital'},
#   'payload': {'ref': '0.1.22',
#    'ref_type': 'tag',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-06-28T05:28:39Z'},
#  {'id': '9911330761',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 8593673,
#    'login': 'derrickmehaffy',
#    'display_login': 'derrickmehaffy',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/derrickmehaffy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8593673?'},
#   'repo': {'id': 133168196,
#    'name': 'canonn-science/CAPIv2-Strapi',
#    'url': 'https://api.github.com/repos/canonn-science/CAPIv2-Strapi'},
#   'payload': {'action': 'opened',
#    'number': 136,
#    'pull_request': {'url': 'https://api.github.com/repos/canonn-science/CAPIv2-Strapi/pulls/136',
#     'id': 292692943,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MjkyNjkyOTQz',
#     'html_url': 'https://github.com/canonn-science/CAPIv2-Strapi/pull/136',
#     'diff_url': 'https://github.com/canonn-science/CAPIv2-Strapi/pull/136.diff',
#     'patch_url': 'https://github.com/canonn-science/CAPIv2-Strapi/pull/136.patch',
#     'issue_url': 'https://api.github.com/repos/canonn-science/CAPIv2-Strapi/issues/136',
#     'number': 136,
#     'state': 'open',
#     'locked': False,
#     'title': 'Update to Strapi Beta.8',
#     'user': {'login': 'derrickmehaffy',
#      'id': 8593673,
#      'node_id': 'MDQ6VXNlcjg1OTM2NzM=',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/8593673?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/derrickmehaffy',
#      'html_url': 'https://github.com/derrickmehaffy',
#      'followers_url': 'https://api.github.com/users/derrickmehaffy/followers',
#      'following_url': 'https://api.github.com/users/derrickmehaffy/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/derrickmehaffy/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/derrickmehaffy/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/derrickmehaffy/subscriptions',
#      'organizations_url': 'https://api.github.com/users/derrickmehaffy/orgs',
#      'repos_url': 'https://api.github.com/users/derrickmehaffy/repos',
#      'events_url': 'https://api.github.com/users/derrickmehaffy/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/derrickmehaffy/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': 'Also added in primaryStar and fixed TBsites in example DB seed',
#     'created_at': '2019-06-28T05:28:37Z',
#     'updated_at': '2019-06-28T05:28:37Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'commits_url': 'https://api.github.com/repos/canonn-science/CAPIv2-Strapi/pulls/136/commits',
#     'review_comments_url': 'https://api.github.com/repos/canonn-science/CAPIv2-Strapi/pulls/136/comments',
#     'review_comment_url': 'https://api.github.com/repos/canonn-science/CAPIv2-Strapi/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/canonn-science/CAPIv2-Strapi/issues/136/comments',
#     'statuses_url': 'https://api.github.com/repos/canonn-science/CAPIv2-Strapi/statuses/9d6e078d0a74179b0ad95703fc26fefd9bf53755',
#     'head': {'label': 'canonn-science:update/v2.0.27',
#      'ref': 'update/v2.0.27',
#      'sha': '9d6e078d0a74179b0ad95703fc26fefd9bf53755',
#      'user': {'login': 'canonn-science',
#       'id': 25851850,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjI1ODUxODUw',
#       'avatar_url': 'https://avatars0.githubusercontent.com/u/25851850?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/canonn-science',
#       'html_url': 'https://github.com/canonn-science',
#       'followers_url': 'https://api.github.com/users/canonn-science/followers',
#       'following_url': 'https://api.github.com/users/canonn-science/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/canonn-science/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/canonn-science/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/canonn-science/subscriptions',
#       'organizations_url': 'https://api.github.com/users/canonn-science/orgs',
#       'repos_url': 'https://api.github.com/users/canonn-science/repos',
#       'events_url': 'https://api.github.com/users/canonn-science/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/canonn-science/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 133168196,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxMzMxNjgxOTY=',
#       'name': 'CAPIv2-Strapi',
#       'full_name': 'canonn-science/CAPIv2-Strapi',
#       'private': False,
#       'owner': {'login': 'canonn-science',
#        'id': 25851850,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjI1ODUxODUw',
#        'avatar_url': 'https://avatars0.githubusercontent.com/u/25851850?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/canonn-science',
#        'html_url': 'https://github.com/canonn-science',
#        'followers_url': 'https://api.github.com/users/canonn-science/followers',
#        'following_url': 'https://api.github.com/users/canonn-science/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/canonn-science/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/canonn-science/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/canonn-science/subscriptions',
#        'organizations_url': 'https://api.github.com/users/canonn-science/orgs',
#        'repos_url': 'https://api.github.com/users/canonn-science/repos',
#        'events_url': 'https://api.github.com/users/canonn-science/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/canonn-science/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/canonn-science/CAPIv2-Strapi',
#       'description': 'Canonn APIv2',
#       'fork': False,
#       'url': 'https://api.github.com/repos/canonn-science/CAPIv2-Strapi',
#       'forks_url': 'https://api.github.com/repos/canonn-science/CAPIv2-Strapi/forks',
#       'keys_url': 'https://api.github.com/repos/canonn-science/CAPIv2-Strapi/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/canonn-science/CAPIv2-Strapi/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/canonn-science/CAPIv2-Strapi/teams',
#       'hooks_url': 'https://api.github.com/repos/canonn-science/CAPIv2-Strapi/hooks',
#       'issue_events_url': 'https://api.github.com/repos/canonn-science/CAPIv2-Strapi/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/canonn-science/CAPIv2-Strapi/events',
#       'assignees_url': 'https://api.github.com/repos/canonn-science/CAPIv2-Strapi/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/canonn-science/CAPIv2-Strapi/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/canonn-science/CAPIv2-Strapi/tags',
#       'blobs_url': 'https://api.github.com/repos/canonn-science/CAPIv2-Strapi/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/canonn-science/CAPIv2-Strapi/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/canonn-science/CAPIv2-Strapi/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/canonn-science/CAPIv2-Strapi/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/canonn-science/CAPIv2-Strapi/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/canonn-science/CAPIv2-Strapi/languages',
#       'stargazers_url': 'https://api.github.com/repos/canonn-science/CAPIv2-Strapi/stargazers',
#       'contributors_url': 'https://api.github.com/repos/canonn-science/CAPIv2-Strapi/contributors',
#       'subscribers_url': 'https://api.github.com/repos/canonn-science/CAPIv2-Strapi/subscribers',
#       'subscription_url': 'https://api.github.com/repos/canonn-science/CAPIv2-Strapi/subscription',
#       'commits_url': 'https://api.github.com/repos/canonn-science/CAPIv2-Strapi/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/canonn-science/CAPIv2-Strapi/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/canonn-science/CAPIv2-Strapi/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/canonn-science/CAPIv2-Strapi/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/canonn-science/CAPIv2-Strapi/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/canonn-science/CAPIv2-Strapi/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/canonn-science/CAPIv2-Strapi/merges',
#       'archive_url': 'https://api.github.com/repos/canonn-science/CAPIv2-Strapi/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/canonn-science/CAPIv2-Strapi/downloads',
#       'issues_url': 'https://api.github.com/repos/canonn-science/CAPIv2-Strapi/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/canonn-science/CAPIv2-Strapi/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/canonn-science/CAPIv2-Strapi/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/canonn-science/CAPIv2-Strapi/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/canonn-science/CAPIv2-Strapi/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/canonn-science/CAPIv2-Strapi/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/canonn-science/CAPIv2-Strapi/deployments',
#       'created_at': '2018-05-12T17:25:27Z',
#       'updated_at': '2019-06-25T03:17:57Z',
#       'pushed_at': '2019-06-28T04:32:40Z',
#       'git_url': 'git://github.com/canonn-science/CAPIv2-Strapi.git',
#       'ssh_url': 'git@github.com:canonn-science/CAPIv2-Strapi.git',
#       'clone_url': 'https://github.com/canonn-science/CAPIv2-Strapi.git',
#       'svn_url': 'https://github.com/canonn-science/CAPIv2-Strapi',
#       'homepage': 'https://api.canonn.tech',
#       'size': 196583,
#       'stargazers_count': 14,
#       'watchers_count': 14,
#       'language': 'TSQL',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'forks_count': 1,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 9,
#       'license': {'key': 'gpl-3.0',
#        'name': 'GNU General Public License v3.0',
#        'spdx_id': 'GPL-3.0',
#        'url': 'https://api.github.com/licenses/gpl-3.0',
#        'node_id': 'MDc6TGljZW5zZTk='},
#       'forks': 1,
#       'open_issues': 9,
#       'watchers': 14,
#       'default_branch': 'development'}},
#     'base': {'label': 'canonn-science:development',
#      'ref': 'development',
#      'sha': '5212f803daded52429b65e244ad1873110394590',
#      'user': {'login': 'canonn-science',
#       'id': 25851850,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjI1ODUxODUw',
#       'avatar_url': 'https://avatars0.githubusercontent.com/u/25851850?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/canonn-science',
#       'html_url': 'https://github.com/canonn-science',
#       'followers_url': 'https://api.github.com/users/canonn-science/followers',
#       'following_url': 'https://api.github.com/users/canonn-science/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/canonn-science/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/canonn-science/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/canonn-science/subscriptions',
#       'organizations_url': 'https://api.github.com/users/canonn-science/orgs',
#       'repos_url': 'https://api.github.com/users/canonn-science/repos',
#       'events_url': 'https://api.github.com/users/canonn-science/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/canonn-science/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 133168196,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxMzMxNjgxOTY=',
#       'name': 'CAPIv2-Strapi',
#       'full_name': 'canonn-science/CAPIv2-Strapi',
#       'private': False,
#       'owner': {'login': 'canonn-science',
#        'id': 25851850,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjI1ODUxODUw',
#        'avatar_url': 'https://avatars0.githubusercontent.com/u/25851850?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/canonn-science',
#        'html_url': 'https://github.com/canonn-science',
#        'followers_url': 'https://api.github.com/users/canonn-science/followers',
#        'following_url': 'https://api.github.com/users/canonn-science/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/canonn-science/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/canonn-science/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/canonn-science/subscriptions',
#        'organizations_url': 'https://api.github.com/users/canonn-science/orgs',
#        'repos_url': 'https://api.github.com/users/canonn-science/repos',
#        'events_url': 'https://api.github.com/users/canonn-science/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/canonn-science/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/canonn-science/CAPIv2-Strapi',
#       'description': 'Canonn APIv2',
#       'fork': False,
#       'url': 'https://api.github.com/repos/canonn-science/CAPIv2-Strapi',
#       'forks_url': 'https://api.github.com/repos/canonn-science/CAPIv2-Strapi/forks',
#       'keys_url': 'https://api.github.com/repos/canonn-science/CAPIv2-Strapi/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/canonn-science/CAPIv2-Strapi/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/canonn-science/CAPIv2-Strapi/teams',
#       'hooks_url': 'https://api.github.com/repos/canonn-science/CAPIv2-Strapi/hooks',
#       'issue_events_url': 'https://api.github.com/repos/canonn-science/CAPIv2-Strapi/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/canonn-science/CAPIv2-Strapi/events',
#       'assignees_url': 'https://api.github.com/repos/canonn-science/CAPIv2-Strapi/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/canonn-science/CAPIv2-Strapi/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/canonn-science/CAPIv2-Strapi/tags',
#       'blobs_url': 'https://api.github.com/repos/canonn-science/CAPIv2-Strapi/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/canonn-science/CAPIv2-Strapi/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/canonn-science/CAPIv2-Strapi/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/canonn-science/CAPIv2-Strapi/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/canonn-science/CAPIv2-Strapi/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/canonn-science/CAPIv2-Strapi/languages',
#       'stargazers_url': 'https://api.github.com/repos/canonn-science/CAPIv2-Strapi/stargazers',
#       'contributors_url': 'https://api.github.com/repos/canonn-science/CAPIv2-Strapi/contributors',
#       'subscribers_url': 'https://api.github.com/repos/canonn-science/CAPIv2-Strapi/subscribers',
#       'subscription_url': 'https://api.github.com/repos/canonn-science/CAPIv2-Strapi/subscription',
#       'commits_url': 'https://api.github.com/repos/canonn-science/CAPIv2-Strapi/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/canonn-science/CAPIv2-Strapi/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/canonn-science/CAPIv2-Strapi/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/canonn-science/CAPIv2-Strapi/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/canonn-science/CAPIv2-Strapi/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/canonn-science/CAPIv2-Strapi/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/canonn-science/CAPIv2-Strapi/merges',
#       'archive_url': 'https://api.github.com/repos/canonn-science/CAPIv2-Strapi/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/canonn-science/CAPIv2-Strapi/downloads',
#       'issues_url': 'https://api.github.com/repos/canonn-science/CAPIv2-Strapi/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/canonn-science/CAPIv2-Strapi/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/canonn-science/CAPIv2-Strapi/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/canonn-science/CAPIv2-Strapi/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/canonn-science/CAPIv2-Strapi/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/canonn-science/CAPIv2-Strapi/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/canonn-science/CAPIv2-Strapi/deployments',
#       'created_at': '2018-05-12T17:25:27Z',
#       'updated_at': '2019-06-25T03:17:57Z',
#       'pushed_at': '2019-06-28T04:32:40Z',
#       'git_url': 'git://github.com/canonn-science/CAPIv2-Strapi.git',
#       'ssh_url': 'git@github.com:canonn-science/CAPIv2-Strapi.git',
#       'clone_url': 'https://github.com/canonn-science/CAPIv2-Strapi.git',
#       'svn_url': 'https://github.com/canonn-science/CAPIv2-Strapi',
#       'homepage': 'https://api.canonn.tech',
#       'size': 196583,
#       'stargazers_count': 14,
#       'watchers_count': 14,
#       'language': 'TSQL',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'forks_count': 1,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 9,
#       'license': {'key': 'gpl-3.0',
#        'name': 'GNU General Public License v3.0',
#        'spdx_id': 'GPL-3.0',
#        'url': 'https://api.github.com/licenses/gpl-3.0',
#        'node_id': 'MDc6TGljZW5zZTk='},
#       'forks': 1,
#       'open_issues': 9,
#       'watchers': 14,
#       'default_branch': 'development'}},
# ...
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'commits_url': 'https://api.github.com/repos/alizain/ismaili-volunteer/pulls/487/commits',
#     'review_comments_url': 'https://api.github.com/repos/alizain/ismaili-volunteer/pulls/487/comments',
#     'review_comment_url': 'https://api.github.com/repos/alizain/ismaili-volunteer/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/alizain/ismaili-volunteer/issues/487/comments',
#     'statuses_url': 'https://api.github.com/repos/alizain/ismaili-volunteer/statuses/ca195c256be06c5356bc19caa2a9da344053e52b',
#     'head': {'label': 'alizain:dependabot/hex/plug_cowboy-2.1.0',
#      'ref': 'dependabot/hex/plug_cowboy-2.1.0',
#      'sha': 'ca195c256be06c5356bc19caa2a9da344053e52b',
#      'user': {'login': 'alizain',
#       'id': 2343007,
#       'node_id': 'MDQ6VXNlcjIzNDMwMDc=',
#       'avatar_url': 'https://avatars2.githubusercontent.com/u/2343007?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/alizain',
#       'html_url': 'https://github.com/alizain',
#       'followers_url': 'https://api.github.com/users/alizain/followers',
#       'following_url': 'https://api.github.com/users/alizain/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/alizain/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/alizain/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/alizain/subscriptions',
#       'organizations_url': 'https://api.github.com/users/alizain/orgs',
#       'repos_url': 'https://api.github.com/users/alizain/repos',
#       'events_url': 'https://api.github.com/users/alizain/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/alizain/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 111722247,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxMTE3MjIyNDc=',
#       'name': 'ismaili-volunteer',
#       'full_name': 'alizain/ismaili-volunteer',
#       'private': False,
#       'owner': {'login': 'alizain',
#        'id': 2343007,
#        'node_id': 'MDQ6VXNlcjIzNDMwMDc=',
#        'avatar_url': 'https://avatars2.githubusercontent.com/u/2343007?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/alizain',
#        'html_url': 'https://github.com/alizain',
#        'followers_url': 'https://api.github.com/users/alizain/followers',
#        'following_url': 'https://api.github.com/users/alizain/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/alizain/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/alizain/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/alizain/subscriptions',
#        'organizations_url': 'https://api.github.com/users/alizain/orgs',
#        'repos_url': 'https://api.github.com/users/alizain/repos',
#        'events_url': 'https://api.github.com/users/alizain/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/alizain/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/alizain/ismaili-volunteer',
#       'description': 'Core server for IsmailiVolunteer',
#       'fork': False,
#       'url': 'https://api.github.com/repos/alizain/ismaili-volunteer',
#       'forks_url': 'https://api.github.com/repos/alizain/ismaili-volunteer/forks',
#       'keys_url': 'https://api.github.com/repos/alizain/ismaili-volunteer/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/alizain/ismaili-volunteer/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/alizain/ismaili-volunteer/teams',
#       'hooks_url': 'https://api.github.com/repos/alizain/ismaili-volunteer/hooks',
#       'issue_events_url': 'https://api.github.com/repos/alizain/ismaili-volunteer/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/alizain/ismaili-volunteer/events',
#       'assignees_url': 'https://api.github.com/repos/alizain/ismaili-volunteer/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/alizain/ismaili-volunteer/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/alizain/ismaili-volunteer/tags',
#       'blobs_url': 'https://api.github.com/repos/alizain/ismaili-volunteer/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/alizain/ismaili-volunteer/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/alizain/ismaili-volunteer/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/alizain/ismaili-volunteer/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/alizain/ismaili-volunteer/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/alizain/ismaili-volunteer/languages',
#       'stargazers_url': 'https://api.github.com/repos/alizain/ismaili-volunteer/stargazers',
#       'contributors_url': 'https://api.github.com/repos/alizain/ismaili-volunteer/contributors',
#       'subscribers_url': 'https://api.github.com/repos/alizain/ismaili-volunteer/subscribers',
#       'subscription_url': 'https://api.github.com/repos/alizain/ismaili-volunteer/subscription',
#       'commits_url': 'https://api.github.com/repos/alizain/ismaili-volunteer/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/alizain/ismaili-volunteer/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/alizain/ismaili-volunteer/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/alizain/ismaili-volunteer/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/alizain/ismaili-volunteer/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/alizain/ismaili-volunteer/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/alizain/ismaili-volunteer/merges',
#       'archive_url': 'https://api.github.com/repos/alizain/ismaili-volunteer/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/alizain/ismaili-volunteer/downloads',
#       'issues_url': 'https://api.github.com/repos/alizain/ismaili-volunteer/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/alizain/ismaili-volunteer/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/alizain/ismaili-volunteer/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/alizain/ismaili-volunteer/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/alizain/ismaili-volunteer/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/alizain/ismaili-volunteer/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/alizain/ismaili-volunteer/deployments',
#       'created_at': '2017-11-22T19:04:32Z',
#       'updated_at': '2019-06-27T06:04:38Z',
#       'pushed_at': '2019-06-28T05:28:36Z',
#       'git_url': 'git://github.com/alizain/ismaili-volunteer.git',
#       'ssh_url': 'git@github.com:alizain/ismaili-volunteer.git',
#       'clone_url': 'https://github.com/alizain/ismaili-volunteer.git',
#       'svn_url': 'https://github.com/alizain/ismaili-volunteer',
#       'homepage': '',
#       'size': 18156,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Elixir',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 26,
#       'license': None,
#       'forks': 0,
#       'open_issues': 26,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'alizain:master',
#      'ref': 'master',
#      'sha': 'be5f588612ff3b5e54dd9b5497bd6771afdade39',
#      'user': {'login': 'alizain',
#       'id': 2343007,
#       'node_id': 'MDQ6VXNlcjIzNDMwMDc=',
#       'avatar_url': 'https://avatars2.githubusercontent.com/u/2343007?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/alizain',
#       'html_url': 'https://github.com/alizain',
#       'followers_url': 'https://api.github.com/users/alizain/followers',
#       'following_url': 'https://api.github.com/users/alizain/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/alizain/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/alizain/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/alizain/subscriptions',
#       'organizations_url': 'https://api.github.com/users/alizain/orgs',
#       'repos_url': 'https://api.github.com/users/alizain/repos',
#       'events_url': 'https://api.github.com/users/alizain/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/alizain/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 111722247,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxMTE3MjIyNDc=',
#       'name': 'ismaili-volunteer',
#       'full_name': 'alizain/ismaili-volunteer',
#       'private': False,
#       'owner': {'login': 'alizain',
#        'id': 2343007,
#        'node_id': 'MDQ6VXNlcjIzNDMwMDc=',
#        'avatar_url': 'https://avatars2.githubusercontent.com/u/2343007?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/alizain',
#        'html_url': 'https://github.com/alizain',
#        'followers_url': 'https://api.github.com/users/alizain/followers',
#        'following_url': 'https://api.github.com/users/alizain/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/alizain/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/alizain/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/alizain/subscriptions',
#        'organizations_url': 'https://api.github.com/users/alizain/orgs',
#        'repos_url': 'https://api.github.com/users/alizain/repos',
#        'events_url': 'https://api.github.com/users/alizain/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/alizain/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/alizain/ismaili-volunteer',
#       'description': 'Core server for IsmailiVolunteer',
#       'fork': False,
#       'url': 'https://api.github.com/repos/alizain/ismaili-volunteer',
#       'forks_url': 'https://api.github.com/repos/alizain/ismaili-volunteer/forks',
#       'keys_url': 'https://api.github.com/repos/alizain/ismaili-volunteer/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/alizain/ismaili-volunteer/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/alizain/ismaili-volunteer/teams',
#       'hooks_url': 'https://api.github.com/repos/alizain/ismaili-volunteer/hooks',
#       'issue_events_url': 'https://api.github.com/repos/alizain/ismaili-volunteer/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/alizain/ismaili-volunteer/events',
#       'assignees_url': 'https://api.github.com/repos/alizain/ismaili-volunteer/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/alizain/ismaili-volunteer/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/alizain/ismaili-volunteer/tags',
#       'blobs_url': 'https://api.github.com/repos/alizain/ismaili-volunteer/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/alizain/ismaili-volunteer/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/alizain/ismaili-volunteer/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/alizain/ismaili-volunteer/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/alizain/ismaili-volunteer/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/alizain/ismaili-volunteer/languages',
#       'stargazers_url': 'https://api.github.com/repos/alizain/ismaili-volunteer/stargazers',
#       'contributors_url': 'https://api.github.com/repos/alizain/ismaili-volunteer/contributors',
#       'subscribers_url': 'https://api.github.com/repos/alizain/ismaili-volunteer/subscribers',
#       'subscription_url': 'https://api.github.com/repos/alizain/ismaili-volunteer/subscription',
#       'commits_url': 'https://api.github.com/repos/alizain/ismaili-volunteer/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/alizain/ismaili-volunteer/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/alizain/ismaili-volunteer/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/alizain/ismaili-volunteer/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/alizain/ismaili-volunteer/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/alizain/ismaili-volunteer/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/alizain/ismaili-volunteer/merges',
#       'archive_url': 'https://api.github.com/repos/alizain/ismaili-volunteer/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/alizain/ismaili-volunteer/downloads',
#       'issues_url': 'https://api.github.com/repos/alizain/ismaili-volunteer/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/alizain/ismaili-volunteer/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/alizain/ismaili-volunteer/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/alizain/ismaili-volunteer/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/alizain/ismaili-volunteer/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/alizain/ismaili-volunteer/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/alizain/ismaili-volunteer/deployments',
#       'created_at': '2017-11-22T19:04:32Z',
#       'updated_at': '2019-06-27T06:04:38Z',
#       'pushed_at': '2019-06-28T05:28:36Z',
#       'git_url': 'git://github.com/alizain/ismaili-volunteer.git',
#       'ssh_url': 'git@github.com:alizain/ismaili-volunteer.git',
#       'clone_url': 'https://github.com/alizain/ismaili-volunteer.git',
#       'svn_url': 'https://github.com/alizain/ismaili-volunteer',
#       'homepage': '',
#       'size': 18156,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Elixir',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 26,
#       'license': None,
#       'forks': 0,
#       'open_issues': 26,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/alizain/ismaili-volunteer/pulls/487'},
#      'html': {'href': 'https://github.com/alizain/ismaili-volunteer/pull/487'},
#      'issue': {'href': 'https://api.github.com/repos/alizain/ismaili-volunteer/issues/487'},
#      'comments': {'href': 'https://api.github.com/repos/alizain/ismaili-volunteer/issues/487/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/alizain/ismaili-volunteer/pulls/487/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/alizain/ismaili-volunteer/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/alizain/ismaili-volunteer/pulls/487/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/alizain/ismaili-volunteer/statuses/ca195c256be06c5356bc19caa2a9da344053e52b'}},
#     'author_association': 'CONTRIBUTOR',
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 1,
#     'deletions': 1,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2019-06-28T05:28:37Z'}]

# %% [markdown]
# ## 其它用法

# %%
payload = {'key1': 'value1', 'key2': 'value2'}
r = requests.get("http://httpbin.org/get", params=payload)
json.loads(r.text)
# Out:
# {'args': {'key1': 'value1', 'key2': 'value2'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.19.1'},
#  'origin': '123.195.194.127, 123.195.194.127',
#  'url': 'https://httpbin.org/get?key1=value1&key2=value2'}

# %%
r = requests.post('http://httpbin.org/post', data = {'key':'value'})
json.loads(r.text)
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'key': 'value'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '9',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.19.1'},
#  'json': None,
#  'origin': '123.195.194.127, 123.195.194.127',
#  'url': 'https://httpbin.org/post'}

# %%
r = requests.post('http://httpbin.org/post', data = {'key':'value'})
json.loads(r.text)

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)
